# %%
##python -m venv .venv  to create virtual environment

# %%
## 3 types of data in ML
### 1. Structured data
### 2. Unstructured data
### 3. Semi-Structured data

# %%
## where to get dataset
### kaggle, google dataset search, ucl ml repository, can use ai tools to find dataset
### openpyxl and pyarrow are used to load excel and parquet files

# %%
# %pip install -q pandas openpyxl pyarrow
# Out:
# [notice] A new release of pip is available: 25.2 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import pandas as pd

# %%
df_csv = pd.read_csv('titanic.csv')
df_csv.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df_csv_subject = pd.read_csv(
    filepath_or_buffer= "titanic.csv",
    usecols= [ "Survived", "Pclass",  "Age"]
)
df_csv_subject.head()
# Out:
#    Survived  Pclass   Age
# 0         0       3  22.0
# 1         1       1  38.0
# 2         1       3  26.0
# 3         1       1  35.0
# 4         0       3  35.0

# %%
df_csv.shape
# Out:
# (891, 12)

# %%
#load first N row
df_csv_preview = pd.read_csv("titanic.csv", nrows=5)

# %%
df_csv_preview.shape
# Out:
# (5, 12)

# %%
## load excel files
df_excel = pd.read_excel("titanic.xlsx")
df_excel.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df_excel_subset = pd.read_excel(
    io= "titanic.xlsx",
    usecols= [ "Survived", "Pclass",  "Age"]
)
df_excel_subset.head()
# Out:
#    Survived  Pclass   Age
# 0         0       3  22.0
# 1         1       1  38.0
# 2         1       3  26.0
# 3         1       1  35.0
# 4         0       3  35.0

# %%
# check sheet names
xls = pd.ExcelFile("titanic.xlsx")
print(xls.sheet_names)
# Out:
# ['Sheet1']

# %%
# To read a specific sheet, you can use the sheet_name parameter in the read_excel function. For example, to read the first sheet, you can do:
df_first_sheet = pd.read_excel("titanic.xlsx", sheet_name="Sheet1")

# %%
# Load parquet files.   parquet is a columnar storage file format that is optimized for use with big data processing frameworks like Apache Spark and Hadoop. It is designed to be efficient in terms of both storage and query performance, making it a popular choice for storing large datasets.
df_parquet = pd.read_parquet("titanic.parquet")
df_parquet.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
## Load the csv file with different separators.  The default separator is a comma, but you can specify a different separator using the sep parameter. For example, to load a CSV file with a tab separator, you can do:
df_csv_tab = pd.read_csv("titanic_tab.csv", sep="\t") # if it separated by column we use sep = ";"
df_csv_tab.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# compare file sizes
csv_file_size = os.path.getsize("titanic.csv")
excel_file_size = os.path.getsize("titanic.xlsx")
parquet_file_size = os.path.getsize("titanic.parquet")

# %%
csv_file_size, excel_file_size, parquet_file_size
# Out:
# (60302, 68829, 41399)

# %%
def file_size(file_path):
    size_bytes = os.path.getsize(file_path)
    size_kb = size_bytes / 1024
    size_mb = size_kb / 1024
    return size_bytes, size_kb, size_mb

for f in ["titanic.csv", "titanic.xlsx", "titanic.parquet"]:
    size_bytes, size_kb, size_mb = file_size(f)
    print(f"{f}: {size_bytes} bytes, {size_kb:.2f} KB, {size_mb:.2f} MB")
# Out:
# titanic.csv: 60302 bytes, 58.89 KB, 0.06 MB
# titanic.xlsx: 68829 bytes, 67.22 KB, 0.07 MB
# titanic.parquet: 41399 bytes, 40.43 KB, 0.04 MB

# %% [markdown]
# ### loading data from a database

# %%
# %pip install SQLAlchemy psycopg2-binary
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 12.0 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 10.7 MB/s  0:00:00 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [psycopg2-binary]
# ...
#
# [notice] A new release of pip is available: 25.2 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
## connect to postgresql database

connection_string = "postgresql://postgres:password@localhost:5432/ml_db"
engine = create_engine(connection_string)

# %%
# load data from csv file to postgresql db table
query =  "SELECT * FROM datasets.diabetes"

df = pd.read_sql(query, con = engine)

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1
